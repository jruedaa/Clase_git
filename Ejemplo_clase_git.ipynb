# %%
print("Ejemplo clase git hub y git")
# Out:
# Ejemplo clase git hub y git

# %%
# prompt: mount drive y crear path para sys y para directorio de trabajo

from google.colab import drive
drive.mount('/content/drive')

import sys
sys.path.append('/content/drive/My Drive/Aplicaciones_analitica/Repositorios/cod_1/Clase_git') # Reemplaza 'Colab Notebooks' con tu directorio si es diferente

# Define el directorio de trabajo
import os
os.chdir('/content/drive/My Drive/Aplicaciones_analitica/Repositorios/cod_1/Clase_git') # Reemplaza con tu directorio de trabajo
print(os.getcwd())
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/My Drive/Aplicaciones_analitica/Repositorios/cod_1/Clase_git
